# %%
import numpy as np
import matplotlib.pyplot as plt
import subprocess as sbp

# %%
#to_run = ["make","caixalj","&&","./caixalj"]
#sbp.run(to_run)

# %%
rx = np.array(np.loadtxt("rxlj.txt"))
ry = np.array(np.loadtxt("rylj.txt"))

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80)
for i in range(len(rx[1,:])):
    plt.plot(rx[:,i],ry[:,i],marker='.',markersize=.1)

plt.axvline(0,0,1, color='k')
plt.axvline(1,0,1, color='k')
plt.axhline(0,0,1, color='k')
plt.axhline(1,0,1, color='k')
plt.xlim((0,1))
plt.ylim((0,1))
plt.show()
